# %% [raw]
# ATM machine: Check Balance, Deposit, Withdraw, Transfer, Exit

# %%
balance=2000 #current balance 
def ATM():
    currentBalance=balance #local reference 
    while(True):
        print (""" \nWelcome to GAM Bank
        Please enter one of the following choices:
        1: Check Balance
        2: Deposit 
        3: Withdraw
        4: Transfer
        5: Exit """)
        
        choice=input("\n Enter your choice: ")
        if choice =="1": #Check balance
            checkBalance(currentBalance)
           
        elif  choice =="2":#Deposit
            print("Please enter your bills into the deposit enterence.") #machine action
            depositAmount=int(input("Enter the deposit amount"))
            
            if depositAmount<0: 
                print("Please enter the amount correctly!")
                
            else:
                currentBalance=deposit(depositAmount,currentBalance) # update current balance
            
        elif  choice =="3": #Withdraw
            cash=int(input("Please enter the desired amount"))
            if cash>0: 
                currentBalance=withdraw(cash,currentBalance) # update current balance
                
            else: 
                print ("Sorry, you entered a wrong amount!")
            
        elif  choice =="4": #Transfer
            #transfer()
            amount=int(input("Please enter an amount"))
            if amount>0: 
                Beneficiary=input("Please write a beneficiary account number") 
                
                currentBalance=transfer(amount,currentBalance) # update current balance
           
            else: 
                print ("Sorry, you entered a wrong amount!")
            
            
            
        elif  choice =="5": #Exit the sys
            print ("Exiting..")
            print ("Thank you!")
            break

            exit()

        else:
            print("Incorrect Choice")
    
    return 0

def checkBalance(currentBalance):
    print (f"\nYour current balance is: {currentBalance}")
    return 0

def deposit(depositAmount,currentBalance):
    #Add deposit to current balance
    # print current balance 
    currentBalance = currentBalance + depositAmount
    print (f"You deposit was: {depositAmount}" + f"\nYour current balance is: {currentBalance}")
    
    return currentBalance

def withdraw(cash,currentBalance):
    #substract cash from current balance
    # update current balance
    # print current balance 
    if cash<=currentBalance:
        currentBalance = currentBalance - cash
        print (f"You withdrew: {cash}" + f"\nYour current balance is: {currentBalance}")
    else:
        print ("\nSorry, there is no sufficient amount")
        print ("You can choose another number or 5 to exit the system ")
        
    return currentBalance
    
    
def transfer(amount,currentBalance):
    #substract amount from current balance
    # update current balance
    # print current balance 
    if amount<=currentBalance:
        currentBalance = currentBalance - amount
        print (f"You tranfer: {amount}" + f"\nYour current balance is: {currentBalance}")
        
    else:
        print ("\nSorry, there is no sufficient amount")
        print ("You can choose another number or 5 to exit the system ")
        
    return currentBalance
    
    
def exit():
    return 0
    
ATM()
# Out:
#
# Welcome to GAM Bank
#         Please enter one of the following choices:
#         1: Check Balance
#         2: Deposit
#         3: Withdraw
#         4: Transfer
#         5: Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5d9d61d22257> in <module>
#     102     return 0
#     103
# --> 104 ATM()
#
# <ipython-input-10-5d9d61d22257> in ATM()
#      11         5: Exit """)
#      12
# ---> 13         choice=input("\n Enter your choice: ")
#      14         if choice =="1": #Check balance
#      15             checkBalance(currentBalance)
#
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
# ...
